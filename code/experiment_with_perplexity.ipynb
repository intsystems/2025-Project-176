# %%
import torch
import torch.nn.functional as F
from transformers import AutoModelForCausalLM, AutoTokenizer
import pickle
import argparse
from huggingface_hub import login
from google.colab import userdata
from google.colab import drive
import pandas as pd
import gc
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

drive.mount('/content/drive')
hf_token = userdata.get('hf')
login(token=hf_token)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def cleanup():
    gc.collect()
    torch.cuda.empty_cache()

cleanup()

# %% [markdown]
# # Initialize model

# %%
model_name = "meta-llama/Llama-3.1-8B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype=torch.float16,
    low_cpu_mem_usage=True
)
cleanup()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.

# %% [markdown]
# # Download Dataset

# %% [markdown]
# Here we first analyze the data from Reddit.

# %%
data = pd.read_json("/content/drive/MyDrive/m1p/SubtaskA.jsonl", lines=True)
data = data.iloc[:, :4]

data_reddit = data[data['source'] == 'reddit']
print(data_reddit.head())

label_cohere = data_reddit[data_reddit['model'] == 'cohere'].head(400)
label_human = data_reddit[data_reddit['model'] == 'human'].head(400)
label_chatgpt = data_reddit[data_reddit['model'] == 'chatGPT'].head(400)
label_dolly = data_reddit[data_reddit['model'] == 'dolly'].head(400)
label_davinci = data_reddit[data_reddit['model'] == 'davinci'].head(400)
label_bloomz = data_reddit[data_reddit['model'] == 'bloomz'].head(400)
label_gpt4 = data_reddit[data_reddit['model'] == 'gpt4'].head(400)


smpl_data = pd.concat([label_cohere, label_human, label_chatgpt, label_dolly, label_davinci, label_bloomz, label_gpt4])
cleanup()
# Out:
#                                                     text  label  source  \
# 52365  \nThe English king Henry II was famously invol...      1  reddit
# 52366  \nThe Louisiana Purchase was a major land deal...      1  reddit
# 52367  \nSome historical cultures engaged in the prac...      1  reddit
# 52368  \nWatergate is the name of the scandal surroun...      1  reddit
# 52369  \nIf a king fell in battle, it was considered ...      1  reddit
#
#         model
# 52365  cohere
# 52366  cohere
# 52367  cohere
# 52368  cohere
# 52369  cohere

# %% [markdown]
# # Metrics and function for calculations

# %%
def calculate_entropy(logprobs):
    entropies = []
    for s_lp in logprobs:
        entropies.append([])
        for lp in s_lp:
            mask = ~np.isinf(lp)
            entropies[-1].append(-np.sum(np.array(lp[mask]) * np.exp(lp[mask])))
    return entropies

def calculate_perplexity(token_logprobs):
    N = len(token_logprobs)
    sum_logprobs = np.sum([np.max(logprobs) for logprobs in token_logprobs])
    avg_logprobs = sum_logprobs / N
    perplexity = np.exp(-avg_logprobs)
    return perplexity


def get_logits(text, model, tokenizer):
    inputs = tokenizer(text, truncation=True, max_length=512, return_tensors="pt")

    with torch.no_grad():
        outputs = model(
            **inputs
            )
    logits = outputs.logits[0]
    logits, _ = torch.topk(logits, k=128, dim=-1)
    probs = F.softmax(logits, dim=-1)

    log_probs = torch.log(probs)

    return np.array(log_probs)

def add_metrics_to_dataframe(balanced_data, model, tokenizer):
    mean_entropies, perplexities = [], []

    for text in tqdm(balanced_data['text']):
        log_probs = get_logits(text, model, tokenizer)

        entropies = calculate_entropy(log_probs)
        mean_entropy = np.mean(entropies)
        perplexity = calculate_perplexity(log_probs)

        mean_entropies.append(mean_entropy)
        perplexities.append(perplexity)

    balanced_data['mean_entropy'] = mean_entropies
    balanced_data['perplexity'] = perplexities

    return balanced_data

# %% [markdown]
# # Calculating metrics

# %%
balanced_data = add_metrics_to_dataframe(smpl_data, model, tokenizer)

cleanup()
# Out:
# 100%|██████████| 2800/2800 [1:16:28<00:00,  1.64s/it]

# %% [markdown]
# # Show results

# %%
models = smpl_data["model"].unique()
palette = sns.color_palette("tab10", len(models))

plt.figure(figsize=(12, 8))

for model, color in zip(models, palette):
    model_data = smpl_data[smpl_data["model"] == model]

    plt.scatter(
        model_data["perplexity"],
        model_data["mean_entropy"],
        color=color,
        label=model,
        alpha=0.5
    )

for model, color in zip(models, palette):
    model_data = smpl_data[smpl_data["model"] == model]

    mean_perplexity = model_data["perplexity"].mean()
    mean_entropy = model_data["mean_entropy"].mean()

    plt.scatter(
        mean_perplexity,
        mean_entropy,
        color=color,
        marker='X',
        s=300,
        edgecolor='black',
        linewidths=2
    )

plt.xlabel("Perplexity")
plt.ylabel("Mean Entropy")
plt.title("Scatter Plot of Perplexity vs Mean Entropy by model. Llama-3.1-8B-Instruct for reddit data")
plt.legend(title="Model", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.grid(True)
plt.show()

# %% [markdown]
# Here you can see that the label points are mostly clustered, and some of the clusters do not intersect.

# %% [markdown]
# # Same experement for data from arxiv

# %%
data_arxiv = data[data['source'] == 'arxiv']
print(data_arxiv.head())

label_cohere = data_arxiv[data_arxiv['model'] == 'cohere'].head(400)
label_human = data_arxiv[data_arxiv['model'] == 'human'].head(400)
label_chatgpt = data_arxiv[data_arxiv['model'] == 'chatGPT'].head(400)
label_dolly = data_arxiv[data_arxiv['model'] == 'dolly'].head(400)
label_davinci = data_arxiv[data_arxiv['model'] == 'davinci'].head(400)
label_bloomz = data_arxiv[data_arxiv['model'] == 'bloomz'].head(400)
label_gpt4 = data_arxiv[data_arxiv['model'] == 'gpt4'].head(400)


smpl_data = pd.concat([label_cohere, label_human, label_chatgpt, label_dolly, label_davinci, label_bloomz, label_gpt4])
cleanup()
# Out:
#                                                 text  label source   model
# 0  We consider a system of many polymers in solut...      1  arxiv  cohere
# 1  We present a catalog of 66 YSOs in the Serpens...      1  arxiv  cohere
# 2  Spectroscopic Observations of the Intermediate...      1  arxiv  cohere
# 3  We present a new class of stochastic Lie group...      1  arxiv  cohere
# 4  ALMA as the ideal probe of the solar chromosph...      1  arxiv  cohere

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype=torch.float16,
    low_cpu_mem_usage=True
)
cleanup()
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.

# %%
balanced_data = add_metrics_to_dataframe(smpl_data, model, tokenizer)

cleanup()
# Out:
# 100%|██████████| 2800/2800 [1:07:53<00:00,  1.45s/it]

# %%
models = smpl_data["model"].unique()
palette = sns.color_palette("tab10", len(models))

plt.figure(figsize=(12, 8))

for model, color in zip(models, palette):
    model_data = smpl_data[smpl_data["model"] == model]

    plt.scatter(
        model_data["perplexity"],
        model_data["mean_entropy"],
        color=color,
        label=model,
        alpha=0.5
    )

for model, color in zip(models, palette):
    model_data = smpl_data[smpl_data["model"] == model]

    mean_perplexity = model_data["perplexity"].mean()
    mean_entropy = model_data["mean_entropy"].mean()

    plt.scatter(
        mean_perplexity,
        mean_entropy,
        color=color,
        marker='X',
        s=300,
        edgecolor='black',
        linewidths=2
    )

plt.xlabel("Perplexity")
plt.ylabel("Mean Entropy")
plt.title("Scatter Plot of Perplexity vs Mean Entropy by model. Llama-3.1-8B-Instruct for arxiv data")
plt.legend(title="Model", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.grid(True)
plt.show()

# %% [markdown]
# Perplexity for models and their position relative to each other has changed.
